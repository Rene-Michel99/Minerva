# %%
import tensorflow as tf
import numpy as np
import pickle
import json
import nltk
import random
from nltk.stem.lancaster import LancasterStemmer
stemmer = LancasterStemmer()

# %%
NEXT_QNT = NEURONS = EPOCHS = 0
with open("../Data/iniV2.pickle", "rb") as f:
    NEXT_QNT , NEURONS, EPOCHS = pickle.load(f)
print(NEURONS,EPOCHS)
# Out:
# 64 100

# %%
words = []
labels = []
docs_x = []
docs_y = []

with open("../Data/intents.json","r",encoding='utf-8') as file:
    data = json.load(file)

for i,intent in enumerate(data["intents"]):
    intent["tag"] = "tag"+str(i)

with open("../Data/intents.json","w",encoding='utf-8') as file:
    json.dump(data,file,indent=3,ensure_ascii=False)

# %%
for intent in data["intents"]:
    for pattern in intent["patterns"]:
        wrds = nltk.word_tokenize(pattern)
        words.extend(wrds)
        docs_x.append(wrds)
        docs_y.append(intent["tag"])

    if intent["tag"] not in labels:
        labels.append(intent["tag"])

ponctuations = ["?","'",'"',"!",".",","]
words = [stemmer.stem(w.lower()) for w in words if w not in ponctuations]
words = sorted(list(set(words)))
labels = sorted(labels)

# %%
training = []
output = []

out_empty = [0 for _ in range(len(labels))]

for x, doc in enumerate(docs_x):
    bag = []

    wrds = [stemmer.stem(w.lower()) for w in doc]

    for w in words:
        if w in wrds:
            bag.append(1)
        else:
            bag.append(0)

    output_row = out_empty[:]
    output_row[labels.index(docs_y[x])] = 1

    training.append(bag)
    output.append(output_row)


training = np.array(training)
output = np.array(output)
N_CLASSES = len(output[0])
SHAPE = len(training[0])

# %%
def dense_layers(inputs):
    x = tf.keras.layers.Dense(NEURONS,activation='relu')(inputs)
    x = tf.keras.layers.Dense(NEURONS,activation='relu')(x)
    return x

def classfier_layer(x,N_CLASSES):
    x = tf.keras.layers.Dense(N_CLASSES,activation='softmax',name='classification')(x)
    return x

def final_model(inputs,N_CLASSES):
    dense = dense_layers(inputs)
    
    classfier = classfier_layer(dense,N_CLASSES)
    
    model = tf.keras.Model(inputs=inputs,outputs=classfier)
    
    return model
    
def define_and_compile_model(SHAPE,N_CLASSES):
    inputs = tf.keras.layers.Input(shape=(SHAPE,))
    
    # create the model
    model = final_model(inputs,N_CLASSES)
    
    # compile your model
    model.compile(optimizer='adam',loss='mse',metrics = {'classification' : 'accuracy'})

    return model

# %%
model = define_and_compile_model(SHAPE,N_CLASSES)
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 561)]             0
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                35968
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                4160
# _________________________________________________________________
# classification (Dense)       (None, 173)               11245
# =================================================================
# Total params: 51,373
# Trainable params: 51,373
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(training,output,epochs=EPOCHS)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 3.8685e-04
# Epoch 2/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 0.0021
# Epoch 3/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 0.0033
# Epoch 4/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 0.0077
# Epoch 5/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 0.0101
# Epoch 6/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.0057 - accuracy: 0.0360
# Epoch 7/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 0.0216
# Epoch 8/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 0.0293
# Epoch 9/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.0057 - accuracy: 0.0458
# Epoch 10/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 0.0468
# Epoch 11/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 0.0596
# Epoch 12/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 0.0654
# Epoch 13/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 0.0747
# Epoch 14/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 0.0735
# Epoch 15/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 0.0751
# Epoch 16/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 0.0696
# Epoch 17/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 0.0644
# Epoch 18/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 0.0615
# Epoch 19/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 0.0588
# Epoch 20/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0056 - accuracy: 0.0483
# Epoch 21/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0056 - accuracy: 0.0790
# Epoch 22/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0055 - accuracy: 0.0750
# Epoch 23/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 0.1455
# Epoch 24/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0051 - accuracy: 0.1656
# Epoch 25/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0049 - accuracy: 0.2311
# Epoch 26/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0048 - accuracy: 0.2611
# Epoch 27/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0046 - accuracy: 0.3142
# Epoch 28/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0043 - accuracy: 0.3465
# Epoch 29/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0041 - accuracy: 0.3927
# Epoch 30/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 0.4754
# Epoch 31/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 0.5384
# Epoch 32/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 0.5143
# Epoch 33/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 0.5820
# Epoch 34/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 0.5698
# Epoch 35/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0028 - accuracy: 0.5870
# Epoch 36/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0024 - accuracy: 0.6744
# Epoch 37/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 0.6600
# Epoch 38/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 0.6808
# Epoch 39/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.0021 - accuracy: 0.6855
# Epoch 40/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.0019 - accuracy: 0.7360
# Epoch 41/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 0.7108
# Epoch 42/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 0.7371
# Epoch 43/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 0.7793
# Epoch 44/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 0.7831
# Epoch 45/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 0.8045
# Epoch 46/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 0.7925
# Epoch 47/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 0.8232
# Epoch 48/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 0.8177
# Epoch 49/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.8406
# Epoch 50/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.8461
# Epoch 51/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.8449
# Epoch 52/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 0.8669
# Epoch 53/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 0.8585
# Epoch 54/100
# 18/18 [==============================] - 0s 2ms/step - loss: 9.5461e-04 - accuracy: 0.8739
# Epoch 55/100
# 18/18 [==============================] - 0s 2ms/step - loss: 9.4204e-04 - accuracy: 0.8728
# Epoch 56/100
# 18/18 [==============================] - 0s 2ms/step - loss: 7.7556e-04 - accuracy: 0.8973
# Epoch 57/100
# 18/18 [==============================] - 0s 2ms/step - loss: 8.3003e-04 - accuracy: 0.8885
# Epoch 58/100
# 18/18 [==============================] - 0s 2ms/step - loss: 8.5216e-04 - accuracy: 0.8813
# Epoch 59/100
# 18/18 [==============================] - 0s 2ms/step - loss: 7.9220e-04 - accuracy: 0.8882
# Epoch 60/100
# 18/18 [==============================] - 0s 2ms/step - loss: 6.6170e-04 - accuracy: 0.9134
# Epoch 61/100
# 18/18 [==============================] - 0s 2ms/step - loss: 7.1933e-04 - accuracy: 0.8967
# Epoch 62/100
# 18/18 [==============================] - 0s 2ms/step - loss: 7.7281e-04 - accuracy: 0.8946
# Epoch 63/100
# 18/18 [==============================] - 0s 2ms/step - loss: 7.4766e-04 - accuracy: 0.8956
# Epoch 64/100
# 18/18 [==============================] - 0s 2ms/step - loss: 5.2029e-04 - accuracy: 0.9292
# Epoch 65/100
# 18/18 [==============================] - 0s 1ms/step - loss: 6.6758e-04 - accuracy: 0.9092
# Epoch 66/100
# 18/18 [==============================] - 0s 2ms/step - loss: 6.3151e-04 - accuracy: 0.9121
# Epoch 67/100
# 18/18 [==============================] - 0s 2ms/step - loss: 4.9519e-04 - accuracy: 0.9313
# Epoch 68/100
# 18/18 [==============================] - 0s 2ms/step - loss: 5.4967e-04 - accuracy: 0.9243
# Epoch 69/100
# 18/18 [==============================] - 0s 2ms/step - loss: 5.7430e-04 - accuracy: 0.9200
# Epoch 70/100
# 18/18 [==============================] - 0s 2ms/step - loss: 4.8098e-04 - accuracy: 0.9287
# Epoch 71/100
# 18/18 [==============================] - 0s 2ms/step - loss: 5.5599e-04 - accuracy: 0.9167
# Epoch 72/100
# 18/18 [==============================] - 0s 1ms/step - loss: 5.3699e-04 - accuracy: 0.9186
# Epoch 73/100
# 18/18 [==============================] - 0s 2ms/step - loss: 5.6182e-04 - accuracy: 0.9163
# Epoch 74/100
# 18/18 [==============================] - 0s 2ms/step - loss: 6.0644e-04 - accuracy: 0.9040
# Epoch 75/100
# 18/18 [==============================] - 0s 2ms/step - loss: 5.5613e-04 - accuracy: 0.9145
# Epoch 76/100
# 18/18 [==============================] - 0s 2ms/step - loss: 5.1262e-04 - accuracy: 0.9224
# Epoch 77/100
# 18/18 [==============================] - 0s 2ms/step - loss: 4.5760e-04 - accuracy: 0.9350
# Epoch 78/100
# 18/18 [==============================] - 0s 2ms/step - loss: 4.1058e-04 - accuracy: 0.9418
# Epoch 79/100
# 18/18 [==============================] - 0s 2ms/step - loss: 4.2756e-04 - accuracy: 0.9387
# Epoch 80/100
# 18/18 [==============================] - 0s 2ms/step - loss: 4.5751e-04 - accuracy: 0.9360
# Epoch 81/100
# 18/18 [==============================] - 0s 2ms/step - loss: 4.0176e-04 - accuracy: 0.9409
# Epoch 82/100
# 18/18 [==============================] - 0s 2ms/step - loss: 4.6102e-04 - accuracy: 0.9265
# Epoch 83/100
# 18/18 [==============================] - 0s 2ms/step - loss: 4.4826e-04 - accuracy: 0.9324
# Epoch 84/100
# 18/18 [==============================] - 0s 2ms/step - loss: 3.8384e-04 - accuracy: 0.9421
# Epoch 85/100
# 18/18 [==============================] - 0s 2ms/step - loss: 4.1447e-04 - accuracy: 0.9391
# Epoch 86/100
# 18/18 [==============================] - 0s 2ms/step - loss: 3.1160e-04 - accuracy: 0.9526
# Epoch 87/100
# 18/18 [==============================] - 0s 2ms/step - loss: 3.7979e-04 - accuracy: 0.9393
# Epoch 88/100
# 18/18 [==============================] - 0s 1ms/step - loss: 3.0535e-04 - accuracy: 0.9557
# Epoch 89/100
# 18/18 [==============================] - 0s 2ms/step - loss: 4.0983e-04 - accuracy: 0.9357
# Epoch 90/100
# 18/18 [==============================] - 0s 2ms/step - loss: 3.0858e-04 - accuracy: 0.9531
# Epoch 91/100
# 18/18 [==============================] - 0s 2ms/step - loss: 5.2279e-04 - accuracy: 0.9232
# Epoch 92/100
# 18/18 [==============================] - 0s 2ms/step - loss: 3.6671e-04 - accuracy: 0.9482
# Epoch 93/100
# 18/18 [==============================] - 0s 2ms/step - loss: 4.3263e-04 - accuracy: 0.9346
# Epoch 94/100
# 18/18 [==============================] - 0s 2ms/step - loss: 4.1315e-04 - accuracy: 0.9349
# Epoch 95/100
# 18/18 [==============================] - 0s 2ms/step - loss: 4.3355e-04 - accuracy: 0.9339
# Epoch 96/100
# 18/18 [==============================] - 0s 2ms/step - loss: 3.6882e-04 - accuracy: 0.9429
# Epoch 97/100
# 18/18 [==============================] - 0s 4ms/step - loss: 3.8494e-04 - accuracy: 0.9415
# Epoch 98/100
# 18/18 [==============================] - 0s 2ms/step - loss: 4.0115e-04 - accuracy: 0.9414
# Epoch 99/100
# 18/18 [==============================] - 0s 2ms/step - loss: 4.1463e-04 - accuracy: 0.9380
# Epoch 100/100
# 18/18 [==============================] - 0s 2ms/step - loss: 3.3362e-04 - accuracy: 0.9462

# %%
def bag_of_words(s):
    bag = [0 for _ in range(len(words))]

    ponctuations = ["?","'",'"',"!",".",","]

    s_words = nltk.word_tokenize(s)
    s_words = [stemmer.stem(word.lower()) for word in s_words if word not in ponctuations]

    for se in s_words:
        for i, w in enumerate(words):
            if w == se:
                bag[i] = 1
    bag = np.array(bag)
    return bag

bag = bag_of_words("olá tudo bem?")
bag.shape
# Out:
# (561,)

# %%
bag = bag.reshape((1,561))
predictions = model.predict(bag)
results_index = np.argmax(predictions)

# %%
tag = labels[results_index]

for tg in data['intents']:
    if tg['tag'] == tag:
        responses = tg['responses']
        current_tag = tg

response = random.choice(responses)
confidence = predictions[0][results_index]
print(response,confidence)
# Out:
# Olá como vai? 0.55439335
